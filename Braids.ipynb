# %%
using Revise
include("src/braids.jl")
# Out:
# subscripts (generic function with 1 method)

# %%
σ = Braid{11}.(1:10);

# %%
σ[2]*σ[3]^-1*σ[4]
# Out:
# σ₂σ₃⁻¹σ₄

# %%
a = prod(σ[rand(1:10)]^rand((1,-1)) for i=1:20)

plot(a^4)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:cx, Int64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Int64}, Measures.Length{:cy, Float64}}}((0cx, 0.1cy), (1cx, 0.8cy)), nothing, nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.AbsoluteLength, Measures.Length{:cy, Int64}}, Tuple{Measures.AbsoluteLength, Measures.Length{:cy, Int64}}}((237.0mm, 0cy), (3.0mm, 1cy)), nothing, nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:cx, Int64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Int64}, Measures.Length{:cy, Float64}}}((0cx, 0.7cy), (1cx, 0.1cy)), nothing, nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measure
# ...

# %%
plot(a^4; cols=[i==6 ? "red" : "white" for i=1:11])
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:cx, Int64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Int64}, Measures.Length{:cy, Float64}}}((0cx, 0.1cy), (1cx, 0.8cy)), nothing, nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.AbsoluteLength, Measures.Length{:cy, Int64}}, Tuple{Measures.AbsoluteLength, Measures.Length{:cy, Int64}}}((237.0mm, 0cy), (3.0mm, 1cy)), nothing, nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:cx, Int64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Int64}, Measures.Length{:cy, Float64}}}((0cx, 0.7cy), (1cx, 0.1cy)), nothing, nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measure
# ...

# %%
a
# Out:
# σ₉σ₅σ₁₀⁻¹σ₄⁻¹σ₁₀⁻¹σ₄σ₁σ₈⁻¹σ₇σ₈⁻¹σ₆⁻¹σ₂σ₅⁻¹σ₄⁻¹σ₃⁻¹σ₃σ₉⁻¹σ₄⁻¹σ₉⁻¹σ₈
